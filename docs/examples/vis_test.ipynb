# %%
import pipit as pp
# Path to OTF2 traces
dirname = "../../pipit/tests/data/ping-pong-otf2"

# Use pipit's ``from_otf2`` API to read in the OTF2 traces.
# The result is stored into pipit's Trace data structure.
trace = pp.Trace.from_otf2(dirname)

# Printout the DataFrame component of the Trace.
# print(trace.events)

# %%
import pipit.plotting.core as vis

# %%
trace.plot_timeline()
# Out:
# /home/alex/Programming/CMSC714/pipit/pipit/plotting/core.py:80: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   codes, uniques = pd.factorize(y_tuples, sort=True)
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:470: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(groupby_column)
# /home/alex/Programming/CMSC714/pipit/pipit/plotting/_util.py:465: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   funcs.groupby("Name")["_depth"]
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:470: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(groupby_column)
# /home/alex/Programming/CMSC714/pipit/pipit/plotting/_util.py:465: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   funcs.groupby("Name")["_depth"]
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# /home/alex/Programming/CMSC714/pipit/pipit/trace.py:663: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg = in_bin.groupby("Name")["exc_time_in_bin"].sum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trace.plot_timeline()
#
# File ~/Programming/CMSC714/pipit/pipit/trace.py:690, in Trace.plot_timeline(self, **kwargs)
#     686 def plot_timeline(self, **kwargs):
#     687     # import this lazily to avoid circular dependencies
#     688     from pipit.plotting import core
# --> 690     return core.timeline(self, **kwargs)
#
# File ~/Programming/CMSC714/pipit/pipit/plotting/core.py:391, in timeline(trace, show_depth, instant_events)
#     389 profile = trace.time_profile(num_bins=100).fillna(0)
#     390 func = profile.columns[3:]
# --> 391 select = figure(
#     392     tools="",
#     393     height=80,
#     394     title=(
#     395         "Drag the middle and edges of the selection box to change the range above",
#     396     ),
#     397     # title="Timeline",
#     398     toolbar_location=None,
#     399     y_axis_type=None,
#     400     x_range=(min_ts, max_ts + (max_ts - min_ts) * 0.05),
#     401     # x_axis_location="above",
#     402 )
#     403 bin_size = profile.loc[0]["bin_start"] - profile.loc[0]["bin_end"]
#     404 palette = get_palette(trace)
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/plotting/figure.py:665, in figure(**kwargs)
#     656 def figure(**kwargs: TAny) -> Figure:
#     657     ''' Create a new :class:`~bokeh.plotting.Figure` for plotting.
#     658
#     659     All other keyword arguments are passed to :class:`~bokeh.plotting.Figure`.
#    (...)
#     663
#     664     '''
# --> 665     return Figure(**kwargs)
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/plotting/figure.py:176, in Figure.__init__(self, *arg, **kw)
#     174 def __init__(self, *arg, **kw) -> None:
#     175     opts = FigureOptions(kw)
# --> 176     super().__init__(*arg, **kw)
#     178     self.x_range = get_range(opts.x_range)
#     179     self.y_range = get_range(opts.y_range)
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/model/model.py:128, in Model.__init__(self, **kwargs)
#     121 def __init__(self, **kwargs: Any) -> None:
#     122
#     123     # "id" is popped from **kw in __new__, so in an ideal world I don't
#     124     # think it should be here too. But Python has subtle behavior here, so
#     125     # it is necessary
#     126     kwargs.pop("id", None)
# --> 128     super().__init__(**kwargs)
#     129     default_theme.apply_to_model(self)
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/core/has_props.py:206, in HasProps.__init__(self, **properties)
#     203 self._unstable_themed_values = {}
#     205 for name, value in properties.items():
# --> 206     setattr(self, name, value)
#     208 self._initialized = True
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/core/has_props.py:230, in HasProps.__setattr__(self, name, value)
#     228 properties = self.properties(_with_props=True)
#     229 if name in properties:
# --> 230     return super().__setattr__(name, value)
#     232 descriptor = getattr(self.__class__, name, None)
#     233 if isinstance(descriptor, property): # Python property
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/core/property/descriptors.py:283, in PropertyDescriptor.__set__(self, obj, value, setter)
#     280     class_name = obj.__class__.__name__
#     281     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 283 value = self.property.prepare_value(obj, self.name, value)
#     284 old = self._get(obj)
#     285 self._set(obj, old, value, setter=setter)
#
# File ~/Programming/Tools/miniconda3/envs/pipit-lateness/lib/python3.10/site-packages/bokeh/core/property/bases.py:365, in Property.prepare_value(self, owner, name, value, hint)
#     363 else:
#     364     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 365     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     367 if isinstance(owner, HasProps):
#     368     obj = owner
#
# ValueError: failed to validate Figure(id='1208', ...).title: expected an element of either Null or Instance(Title), got ('Drag the middle and edges of the selection box to change the range above',)
